# %%
import json
import os
import pandas as pd

folder_path = r"C:\Users\ihsiu\Desktop\exa-data-eng-assessment-main\data\sample"

def process_json_files(folder):
    all_key_value_data = []  # List to store individual JSON key-value data

    for filename in os.listdir(folder):
        if filename.endswith(".json"):
            file_path = os.path.join(folder, filename)
            with open(file_path, "r") as json_file:
                data = json.load(json_file)

                entry_data = data.get("entry", [])
                for entry in entry_data:
                    resource_data = entry["resource"]

                    # Extracting key-value pairs from resource
                    entry_key_value_data = [{"Key": key, "Value": value} for key, value in resource_data.items()]
                    all_key_value_data.extend(entry_key_value_data)

                    # Extracting fullUrl
                    full_url = entry.get("fullUrl", None)
                    all_key_value_data.append({"Key": "fullUrl", "Value": full_url})

                    # Extracting nested key-value pairs from request
                    request_data = entry.get("request", {})
                    for key, value in request_data.items():
                        if isinstance(value, dict):
                            for nested_key, nested_value in value.items():
                                all_key_value_data.append({"Key": f"request.{key}.{nested_key}", "Value": nested_value})
                        else:
                            all_key_value_data.append({"Key": f"request.{key}", "Value": value})

    # Create a DataFrame from the combined key-value data
    key_value_df = pd.DataFrame(all_key_value_data)

    return key_value_df

# %%
# Call the function with your folder path
key_value_df = process_json_files(folder_path)
# pd.set_option('display.max_rows', None)

key_value_df
# Out:
#                   Key                                              Value
# 0        resourceType                                            Patient
# 1                  id               cced3031-d98c-d870-5dce-f0086d8c7a34
# 2                meta  {'profile': ['http://hl7.org/fhir/us/core/Stru...
# 3                text  {'status': 'generated', 'div': '<div xmlns="ht...
# 4           extension  [{'url': 'http://hl7.org/fhir/us/core/Structur...
# ...               ...                                                ...
# 37496        recorded                      2021-09-30T06:06:44.325+01:00
# 37497           agent  [{'type': {'coding': [{'system': 'http://termi...
# 37498         fullUrl      urn:uuid:7e44ff49-8fe6-f6af-0dc4-c78bad96b917
# 37499  request.method                                               POST
# 37500     request.url                                         Provenance
#
# [37501 rows x 2 columns]

# %%
df = key_value_df[key_value_df['Key'] == 'resourceType']
df
# Out:
#                 Key                 Value
# 0      resourceType               Patient
# 17     resourceType             Encounter
# 32     resourceType             Condition
# 46     resourceType      DiagnosticReport
# 61     resourceType     DocumentReference
# ...             ...                   ...
# 37419  resourceType      DiagnosticReport
# 37434  resourceType     DocumentReference
# 37450  resourceType                 Claim
# 37468  resourceType  ExplanationOfBenefit
# 37492  resourceType            Provenance
#
# [2399 rows x 2 columns]

# %%
df.groupby('Value').nunique()
# Out:
#                       Key
# Value
# CarePlan                1
# CareTeam                1
# Claim                   1
# Condition               1
# Device                  1
# DiagnosticReport        1
# DocumentReference       1
# Encounter               1
# ExplanationOfBenefit    1
# Immunization            1
# MedicationRequest       1
# Observation             1
# Patient                 1
# Procedure               1
# Provenance              1

# %%
import os
import pandas as pd
import json
import psycopg2

def read_nested_json(file_path):
    with open(file_path, 'r', encoding="utf8") as file:
        data = json.load(file)
    return data

def normalize_nested_json(data):
    # Use pandas json_normalize() to flatten the nested JSON data
    df = pd.json_normalize(data, record_path=['entry'], max_level=2, sep='_')
    return df

def process_json_files(json_directory):
    
    all_dataframes = []

    # Iterate through all files in the directory
    for filename in os.listdir(json_directory):
        if filename.endswith(".json"):
            file_path = os.path.join(json_directory, filename)
            nested_json_data = read_nested_json(file_path)
            normalized_df = normalize_nested_json(nested_json_data)
            all_dataframes.append(normalized_df)

    # Concatenate all dataframes into a single dataframe
    combined_df = pd.concat(all_dataframes, ignore_index=True)
    return combined_df

def create_resource_dataframes(combined_df):
    
    resourceType_lst = combined_df['resource_resourceType'].unique().tolist()

    # Create an empty dictionary to store the dataframes
    dataframes_dict = {}

    # Loop through each resource type and create the respective dataframe
    for rT in resourceType_lst:
        # Filter the rows for the current resource type and drop columns with NaN values
        df = combined_df.loc[combined_df['resource_resourceType'] == rT].dropna(axis=1).convert_dtypes()

        # Store the dataframe in the dictionary with the resource type as the key
        dataframes_dict[rT] = df

    return dataframes_dict
        

if __name__ == "__main__":
    
    json_directory = r"C:\Users\ihsiu\Desktop\exa-data-eng-assessment-main\data"  # Replace this with the path to your directory containing JSON files
    
    combined_df = process_json_files(json_directory)
    dataframes_dict = create_resource_dataframes(combined_df)

    # Now you can access each dataframe using its corresponding resource type as the key
    # For example:
    df_encounter = dataframes_dict['Encounter']
    df_patient = dataframes_dict['Patient']
    df_condition = dataframes_dict['Condition']
    df_diagrep = dataframes_dict['DiagnosticReport']
    df_explan = dataframes_dict['ExplanationOfBenefit']
    df_medreq = dataframes_dict['MedicationRequest']
    df_careteam = dataframes_dict['CareTeam']
    df_careplan = dataframes_dict['CarePlan']
    df_procedure = dataframes_dict['Procedure']
    df_immun = dataframes_dict['Immunization']
    df_observ = dataframes_dict['Observation']
    df_proven = dataframes_dict['Provenance']
    df_device = dataframes_dict['Device']

# %%
combined_df
# Out:
#                                              fullUrl resource_resourceType  \
# 0      urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e               Patient
# 1      urn:uuid:4dbc90e0-b7b2-482c-24af-1405654e59ae             Encounter
# 2      urn:uuid:2b9b5daf-ef78-63c7-3edc-cfc0a209eee0             Condition
# 3      urn:uuid:b6487994-9b3f-7b3c-6e2d-feba134129f9             Condition
# 4      urn:uuid:f76535a7-ac06-3e3c-d0a3-7285fb4c8dd8      DiagnosticReport
# ...                                              ...                   ...
# 63559  urn:uuid:b9a774c6-9582-de86-3593-2460084a0533      DiagnosticReport
# 63560  urn:uuid:71993cc6-3ebc-1e08-0b30-4e518294d124     DocumentReference
# 63561  urn:uuid:33d4ef7d-71ce-82b3-e5d3-01d7bd52aa1a                 Claim
# 63562  urn:uuid:60e0a7dd-16e1-6b8f-3203-3dc18f1b5f15  ExplanationOfBenefit
# 63563  urn:uuid:154d97b0-f436-3b38-89d1-d214cb8df6fa            Provenance
#
#                                 resource_id  \
# 0      8c95253e-8ee8-9ae8-6d40-021d702dc78e
# 1      4dbc90e0-b7b2-482c-24af-1405654e59ae
# 2      2b9b5daf-ef78-63c7-3edc-cfc0a209eee0
# 3      b6487994-9b3f-7b3c-6e2d-feba134129f9
# 4      f76535a7-ac06-3e3c-d0a3-7285fb4c8dd8
# ...                                     ...
# 63559  b9a774c6-9582-de86-3593-2460084a0533
# 63560  71993cc6-3ebc-1e08-0b30-4e518294d124
# 63561  33d4ef7d-71ce-82b3-e5d3-01d7bd52aa1a
# 63562  60e0a7dd-16e1-6b8f-3203-3dc18f1b5f15
# 63563  154d97b0-f436-3b38-89d1-d214cb8df6fa
#
#                                    resource_meta_profile resource_text_status  \
# 0      [http://hl7.org/fhir/us/core/StructureDefiniti...            generated
# 1      [http://hl7.org/fhir/us/core/StructureDefiniti...                  NaN
# 2      [http://hl7.org/fhir/us/core/StructureDefiniti...                  NaN
# 3      [http://hl7.org/fhir/us/core/StructureDefiniti...                  NaN
# 4      [http://hl7.org/fhir/us/core/StructureDefiniti...                  NaN
# ...                                                  ...                  ...
# 63559  [http://hl7.org/fhir/us/core/StructureDefiniti...                  NaN
# 63560  [http://hl7.org/fhir/us/core/StructureDefiniti...                  NaN
# 63561                                                NaN                  NaN
# 63562                                                NaN                  NaN
# 63563  [http://hl7.org/fhir/us/core/StructureDefiniti...                  NaN
#
#                                        resource_text_div  \
# 0      <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 63559                                                NaN
# 63560                                                NaN
# 63561                                                NaN
# 63562                                                NaN
# 63563                                                NaN
#
#                                       resource_extension  \
# 0      [{'url': 'http://hl7.org/fhir/us/core/Structur...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 63559                                                NaN
# 63560                                                NaN
# 63561                                                NaN
# 63562                                                NaN
# 63563                                                NaN
#
#                                      resource_identifier  \
# 0      [{'system': 'https://github.com/synthetichealt...
# 1      [{'use': 'official', 'system': 'https://github...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 63559                                                NaN
# 63560  [{'system': 'urn:ietf:rfc:3986', 'value': 'urn...
# 63561                                                NaN
# 63562  [{'system': 'https://bluebutton.cms.gov/resour...
# 63563                                                NaN
#
#                                            resource_name  \
# 0      [{'use': 'official', 'family': 'Dickens475', '...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 63559                                                NaN
# 63560                                                NaN
# 63561                                                NaN
# 63562                                                NaN
# 63563                                                NaN
#
#                                         resource_telecom  ...  \
# 0      [{'system': 'phone', 'value': '555-152-6034', ...  ...
# 1                                                    NaN  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 63559                                                NaN  ...
# 63560                                                NaN  ...
# 63561                                                NaN  ...
# 63562                                                NaN  ...
# 63563                                                NaN  ...
#
#       resource_lotNumber resource_serialNumber resource_deviceName  \
# 0                    NaN                   NaN                 NaN
# 1                    NaN                   NaN                 NaN
# 2                    NaN                   NaN                 NaN
# 3                    NaN                   NaN                 NaN
# 4                    NaN                   NaN                 NaN
# ...                  ...                   ...                 ...
# 63559                NaN                   NaN                 NaN
# 63560                NaN                   NaN                 NaN
# 63561                NaN                   NaN                 NaN
# 63562                NaN                   NaN                 NaN
# 63563                NaN                   NaN                 NaN
#
#       resource_type_text resource_hospitalization_dischargeDisposition  \
# 0                    NaN                                           NaN
# 1                    NaN                                           NaN
# 2                    NaN                                           NaN
# 3                    NaN                                           NaN
# 4                    NaN                                           NaN
# ...                  ...                                           ...
# 63559                NaN                                           NaN
# 63560                NaN                                           NaN
# 63561                NaN                                           NaN
# 63562                NaN                                           NaN
# 63563                NaN                                           NaN
#
#       resource_multipleBirthInteger resource_suppliedItem_quantity  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
# ...                             ...                            ...
# 63559                           NaN                            NaN
# 63560                           NaN                            NaN
# 63561                           NaN                            NaN
# 63562                           NaN                            NaN
# 63563                           NaN                            NaN
#
#       resource_suppliedItem_itemCodeableConcept resource_dosage_dose  \
# 0                                           NaN                  NaN
# 1                                           NaN                  NaN
# 2                                           NaN                  NaN
# 3                                           NaN                  NaN
# 4                                           NaN                  NaN
# ...                                         ...                  ...
# 63559                                       NaN                  NaN
# 63560                                       NaN                  NaN
# 63561                                       NaN                  NaN
# 63562                                       NaN                  NaN
# 63563                                       NaN                  NaN
#
#       resource_dosage_rateQuantity
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 63559                          NaN
# 63560                          NaN
# 63561                          NaN
# 63562                          NaN
# 63563                          NaN
#
# [63564 rows x 134 columns]

# %%
df_patient
# Out:
#                                              fullUrl resource_resourceType  \
# 0      urn:uuid:8c95253e-8ee8-9ae8-6d40-021d702dc78e               Patient
# 619    urn:uuid:6fa23508-960e-ff22-c3d0-0519a036543b               Patient
# 1552   urn:uuid:83524678-9bff-93b7-ef89-d7f5390072ff               Patient
# 2255   urn:uuid:4e343b0a-8698-b6dd-64c6-c2d2d0959e6e               Patient
# 3216   urn:uuid:6e4ac285-2a8d-a30d-5ecb-e32cb595a876               Patient
# ...                                              ...                   ...
# 60292  urn:uuid:15201e77-7e36-0667-73bc-013783e57649               Patient
# 61622  urn:uuid:f38fe4a9-1634-144c-0147-53c0300c1561               Patient
# 62014  urn:uuid:686e4b2e-1f8d-7018-c335-1604a300121b               Patient
# 62676  urn:uuid:37d57af4-d27f-fb97-9b5c-a1090f5a57b7               Patient
# 63048  urn:uuid:4995ca99-2ab9-3b18-a56e-c33d29e53af0               Patient
#
#                                 resource_id  \
# 0      8c95253e-8ee8-9ae8-6d40-021d702dc78e
# 619    6fa23508-960e-ff22-c3d0-0519a036543b
# 1552   83524678-9bff-93b7-ef89-d7f5390072ff
# 2255   4e343b0a-8698-b6dd-64c6-c2d2d0959e6e
# 3216   6e4ac285-2a8d-a30d-5ecb-e32cb595a876
# ...                                     ...
# 60292  15201e77-7e36-0667-73bc-013783e57649
# 61622  f38fe4a9-1634-144c-0147-53c0300c1561
# 62014  686e4b2e-1f8d-7018-c335-1604a300121b
# 62676  37d57af4-d27f-fb97-9b5c-a1090f5a57b7
# 63048  4995ca99-2ab9-3b18-a56e-c33d29e53af0
#
#                                    resource_meta_profile resource_text_status  \
# 0      [http://hl7.org/fhir/us/core/StructureDefiniti...            generated
# 619    [http://hl7.org/fhir/us/core/StructureDefiniti...            generated
# 1552   [http://hl7.org/fhir/us/core/StructureDefiniti...            generated
# 2255   [http://hl7.org/fhir/us/core/StructureDefiniti...            generated
# 3216   [http://hl7.org/fhir/us/core/StructureDefiniti...            generated
# ...                                                  ...                  ...
# 60292  [http://hl7.org/fhir/us/core/StructureDefiniti...            generated
# 61622  [http://hl7.org/fhir/us/core/StructureDefiniti...            generated
# 62014  [http://hl7.org/fhir/us/core/StructureDefiniti...            generated
# 62676  [http://hl7.org/fhir/us/core/StructureDefiniti...            generated
# 63048  [http://hl7.org/fhir/us/core/StructureDefiniti...            generated
#
#                                        resource_text_div  \
# 0      <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 619    <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 1552   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 2255   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 3216   <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# ...                                                  ...
# 60292  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 61622  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 62014  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 62676  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
# 63048  <div xmlns="http://www.w3.org/1999/xhtml">Gene...
#
#                                       resource_extension  \
# 0      [{'url': 'http://hl7.org/fhir/us/core/Structur...
# 619    [{'url': 'http://hl7.org/fhir/us/core/Structur...
# 1552   [{'url': 'http://hl7.org/fhir/us/core/Structur...
# 2255   [{'url': 'http://hl7.org/fhir/us/core/Structur...
# 3216   [{'url': 'http://hl7.org/fhir/us/core/Structur...
# ...                                                  ...
# 60292  [{'url': 'http://hl7.org/fhir/us/core/Structur...
# 61622  [{'url': 'http://hl7.org/fhir/us/core/Structur...
# 62014  [{'url': 'http://hl7.org/fhir/us/core/Structur...
# 62676  [{'url': 'http://hl7.org/fhir/us/core/Structur...
# 63048  [{'url': 'http://hl7.org/fhir/us/core/Structur...
#
#                                      resource_identifier  \
# 0      [{'system': 'https://github.com/synthetichealt...
# 619    [{'system': 'https://github.com/synthetichealt...
# 1552   [{'system': 'https://github.com/synthetichealt...
# 2255   [{'system': 'https://github.com/synthetichealt...
# 3216   [{'system': 'https://github.com/synthetichealt...
# ...                                                  ...
# 60292  [{'system': 'https://github.com/synthetichealt...
# 61622  [{'system': 'https://github.com/synthetichealt...
# 62014  [{'system': 'https://github.com/synthetichealt...
# 62676  [{'system': 'https://github.com/synthetichealt...
# 63048  [{'system': 'https://github.com/synthetichealt...
#
#                                            resource_name  \
# 0      [{'use': 'official', 'family': 'Dickens475', '...
# 619    [{'use': 'official', 'family': 'Jerde200', 'gi...
# 1552   [{'use': 'official', 'family': 'Price929', 'gi...
# 2255   [{'use': 'official', 'family': 'Hansen121', 'g...
# 3216   [{'use': 'official', 'family': 'Anderson154', ...
# ...                                                  ...
# 60292  [{'use': 'official', 'family': 'Hodkiewicz467'...
# 61622  [{'use': 'official', 'family': 'Conn188', 'giv...
# 62014  [{'use': 'official', 'family': 'Barton704', 'g...
# 62676  [{'use': 'official', 'family': 'Wyman904', 'gi...
# 63048  [{'use': 'official', 'family': 'Schoen8', 'giv...
#
#                                         resource_telecom resource_gender  \
# 0      [{'system': 'phone', 'value': '555-152-6034', ...            male
# 619    [{'system': 'phone', 'value': '555-455-2751', ...            male
# 1552   [{'system': 'phone', 'value': '555-106-9705', ...          female
# 2255   [{'system': 'phone', 'value': '555-675-9219', ...          female
# 3216   [{'system': 'phone', 'value': '555-418-5997', ...          female
# ...                                                  ...             ...
# 60292  [{'system': 'phone', 'value': '555-165-4080', ...          female
# 61622  [{'system': 'phone', 'value': '555-827-4969', ...            male
# 62014  [{'system': 'phone', 'value': '555-559-4415', ...            male
# 62676  [{'system': 'phone', 'value': '555-226-3023', ...            male
# 63048  [{'system': 'phone', 'value': '555-606-8142', ...            male
#
#       resource_birthDate                                   resource_address  \
# 0             1944-08-28  [{'extension': [{'url': 'http://hl7.org/fhir/S...
# 619           2001-06-28  [{'extension': [{'url': 'http://hl7.org/fhir/S...
# 1552          1980-06-10  [{'extension': [{'url': 'http://hl7.org/fhir/S...
# 2255          1946-05-21  [{'extension': [{'url': 'http://hl7.org/fhir/S...
# 3216          1968-07-07  [{'extension': [{'url': 'http://hl7.org/fhir/S...
# ...                  ...                                                ...
# 60292         1946-02-17  [{'extension': [{'url': 'http://hl7.org/fhir/S...
# 61622         1969-04-01  [{'extension': [{'url': 'http://hl7.org/fhir/S...
# 62014         1976-10-22  [{'extension': [{'url': 'http://hl7.org/fhir/S...
# 62676         1970-01-04  [{'extension': [{'url': 'http://hl7.org/fhir/S...
# 63048         1950-08-27  [{'extension': [{'url': 'http://hl7.org/fhir/S...
#
#                            resource_maritalStatus_coding  \
# 0      [{'system': 'http://terminology.hl7.org/CodeSy...
# 619    [{'system': 'http://terminology.hl7.org/CodeSy...
# 1552   [{'system': 'http://terminology.hl7.org/CodeSy...
# 2255   [{'system': 'http://terminology.hl7.org/CodeSy...
# 3216   [{'system': 'http://terminology.hl7.org/CodeSy...
# ...                                                  ...
# 60292  [{'system': 'http://terminology.hl7.org/CodeSy...
# 61622  [{'system': 'http://terminology.hl7.org/CodeSy...
# 62014  [{'system': 'http://terminology.hl7.org/CodeSy...
# 62676  [{'system': 'http://terminology.hl7.org/CodeSy...
# 63048  [{'system': 'http://terminology.hl7.org/CodeSy...
#
#       resource_maritalStatus_text  \
# 0                               M
# 619                 Never Married
# 1552                            S
# 2255                            M
# 3216                            M
# ...                           ...
# 60292                           M
# 61622                           S
# 62014                           S
# 62676                           M
# 63048                           M
#
#                                   resource_communication request_method  \
# 0      [{'language': {'coding': [{'system': 'urn:ietf...           POST
# 619    [{'language': {'coding': [{'system': 'urn:ietf...           POST
# 1552   [{'language': {'coding': [{'system': 'urn:ietf...           POST
# 2255   [{'language': {'coding': [{'system': 'urn:ietf...           POST
# 3216   [{'language': {'coding': [{'system': 'urn:ietf...           POST
# ...                                                  ...            ...
# 60292  [{'language': {'coding': [{'system': 'urn:ietf...           POST
# 61622  [{'language': {'coding': [{'system': 'urn:ietf...           POST
# 62014  [{'language': {'coding': [{'system': 'urn:ietf...           POST
# 62676  [{'language': {'coding': [{'system': 'urn:ietf...           POST
# 63048  [{'language': {'coding': [{'system': 'urn:ietf...           POST
#
#       request_url
# 0         Patient
# 619       Patient
# 1552      Patient
# 2255      Patient
# 3216      Patient
# ...           ...
# 60292     Patient
# 61622     Patient
# 62014     Patient
# 62676     Patient
# 63048     Patient
#
# [79 rows x 18 columns]

# %%
df_immun.dtypes
# Out:
# fullUrl                          string
# resource_resourceType            string
# resource_id                      string
# resource_meta_profile            object
# request_method                   string
# request_url                      string
# resource_status                  string
# resource_encounter_reference     string
# resource_patient_reference       string
# resource_location_reference      string
# resource_location_display        string
# resource_vaccineCode_coding      object
# resource_vaccineCode_text        string
# resource_occurrenceDateTime      string
# resource_primarySource          boolean
# dtype: object
